# %%
# for modifying python scripts on the go
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## with gui

# %%
# for modifying python scripts on the go
# %load_ext autoreload
# %autoreload 2

# %%
from main import startSimulation

# %%
startSimulation()
# Out:
# Initialize Simulator
# Weights loaded into PyTorch model
# Initialize GUI...
# start button pressed
# simulation started with the following parameters: demo mode: True, pred_interval: 0.05, sliding window: 2, pred horizon: 1
# data_sources.hist_dataset - Removing merged dataset
# data_sources.hist_dataset - Saving merged dataset
#
# commencing loop no. 0..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 05:01:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 05:01:00
#
# ---------------------head start loop: {'irradiance': 1.0, 'temperature': 13.3, 'true_power': 2.414069, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'raw'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 05:01:00
# ---------------INPUT:                      irradiance  temperature  true_power  pred_power  \
# 2024-09-06 04:51:00         0.0         13.8    2.414069          -1
# 2024-09-06 05:01:00         1.0         13.3    2.414069          -1
#
#                      pred_time  rmse state
# 2024-09-06 04:51:00         -1    -1   raw
# 2024-09-06 05:01:00         -1    -1   raw
# ---------------OUTPUT: -41.13941015567798
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -41.13941015567798, 'pred_time': 0.96429443359375, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 0: took 0.97 seconds
#
#
# - Sleeping for 2.03 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 1..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 05:11:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 05:11:00
#
# ---------------------head start loop: {'irradiance': 5.0, 'temperature': 13.0, 'true_power': 2.2732483083, 'pred_power': -41.13941015567798, 'pred_time': 0.96429443359375, 'rmse': 0.0019733026574535444, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 05:11:00
# ---------------INPUT:                      irradiance  temperature  true_power  pred_power  \
# 2024-09-06 05:01:00         1.0         13.3    2.414069    -1.00000
# 2024-09-06 05:11:00         5.0         13.0    2.273248   -41.13941
#
#                      pred_time      rmse state
# 2024-09-06 05:01:00  -1.000000 -1.000000   raw
# 2024-09-06 05:11:00   0.964294  0.001973  full
# ---------------OUTPUT: -15.214950144122668
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -15.214950144122668, 'pred_time': 0.993582010269165, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 1: took 1.00 seconds
#
#
# - Sleeping for 2.00 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 2..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 05:21:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 05:21:00
#
# ---------------------head start loop: {'irradiance': 13.0, 'temperature': 13.1, 'true_power': 0.0, 'pred_power': -15.214950144122668, 'pred_time': 0.993582010269165, 'rmse': 0.0014785496658756123, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 05:21:00
# ---------------INPUT:                      irradiance  temperature  true_power  pred_power  \
# 2024-09-06 05:11:00         5.0         13.0    2.273248   -41.13941
# 2024-09-06 05:21:00        13.0         13.1    0.000000   -15.21495
#
#                      pred_time      rmse state
# 2024-09-06 05:11:00   0.964294  0.001973  full
# 2024-09-06 05:21:00   0.993582  0.001479  full
# ---------------OUTPUT: 8.371806718042535
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 8.371806718042535, 'pred_time': 0.946061372756958, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 2: took 0.95 seconds
#
#
# - Sleeping for 2.05 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 3..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 05:31:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 05:31:00
#
# ---------------------head start loop: {'irradiance': 21.0, 'temperature': 13.3, 'true_power': 0.0, 'pred_power': 8.371806718042535, 'pred_time': 0.946061372756958, 'rmse': 0.001227059681430486, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 05:31:00
# ---------------INPUT:                      irradiance  temperature  true_power  pred_power  \
# 2024-09-06 05:21:00        13.0         13.1         0.0  -15.214950
# 2024-09-06 05:31:00        21.0         13.3         0.0    8.371807
#
#                      pred_time      rmse state
# 2024-09-06 05:21:00   0.993582  0.001479  full
# 2024-09-06 05:31:00   0.946061  0.001227  full
# ---------------OUTPUT: 28.71316369366832
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 28.71316369366832, 'pred_time': 0.9833273887634277, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 3: took 0.99 seconds
#
#
# - Sleeping for 2.01 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 4..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 05:41:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 05:41:00
#
# ---------------------head start loop: {'irradiance': 26.0, 'temperature': 14.0, 'true_power': 0.0, 'pred_power': 28.71316369366832, 'pred_time': 0.9833273887634277, 'rmse': 0.0012470391669038496, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 05:41:00
# ---------------INPUT:                      irradiance  temperature  true_power  pred_power  \
# 2024-09-06 05:31:00        21.0         13.3         0.0    8.371807
# 2024-09-06 05:41:00        26.0         14.0         0.0   28.713164
#
#                      pred_time      rmse state
# 2024-09-06 05:31:00   0.946061  0.001227  full
# 2024-09-06 05:41:00   0.983327  0.001247  full
# ---------------OUTPUT: 35.168563961914515
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 35.168563961914515, 'pred_time': 1.1092162132263184, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 4: took 1.12 seconds
#
#
# - Sleeping for 1.88 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 5..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 05:51:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 05:51:00
#
# ---------------------head start loop: {'irradiance': 28.0, 'temperature': 13.4, 'true_power': 0.0, 'pred_power': 35.168563961914515, 'pred_time': 1.1092162132263184, 'rmse': 0.0013248287634501684, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 05:51:00
# ---------------INPUT:                      irradiance  temperature  true_power  pred_power  \
# 2024-09-06 05:41:00        26.0         14.0         0.0   28.713164
# 2024-09-06 05:51:00        28.0         13.4         0.0   35.168564
#
#                      pred_time      rmse state
# 2024-09-06 05:41:00   0.983327  0.001247  full
# 2024-09-06 05:51:00   1.109216  0.001325  full
# ---------------OUTPUT: 34.82859513247422
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 34.82859513247422, 'pred_time': 0.968991756439209, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 5: took 0.97 seconds
#
#
# - Sleeping for 2.03 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 6..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 06:01:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 06:01:00
#
# ---------------------head start loop: {'irradiance': 88.0, 'temperature': 14.1, 'true_power': 0.0, 'pred_power': 34.82859513247422, 'pred_time': 0.968991756439209, 'rmse': 0.0013712596848272007, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 06:01:00
# ---------------INPUT:                      irradiance  temperature  true_power  pred_power  \
# 2024-09-06 05:51:00        28.0         13.4         0.0   35.168564
# 2024-09-06 06:01:00        88.0         14.1         0.0   34.828595
#
#                      pred_time      rmse state
# 2024-09-06 05:51:00   1.109216  0.001325  full
# 2024-09-06 06:01:00   0.968992  0.001371  full
# ---------------OUTPUT: 330.8933556813049
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 330.8933556813049, 'pred_time': 0.9690570831298828, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 6: took 0.97 seconds
#
#
# - Sleeping for 2.03 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 7..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 06:11:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 06:11:00
#
# ---------------------head start loop: {'irradiance': 144.0, 'temperature': 14.7, 'true_power': 0.0, 'pred_power': 330.8933556813049, 'pred_time': 0.9690570831298828, 'rmse': 0.005824848004966536, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 06:11:00
# ---------------INPUT:                      irradiance  temperature  true_power  pred_power  \
# 2024-09-06 06:01:00        88.0         14.1         0.0   34.828595
# 2024-09-06 06:11:00       144.0         14.7         0.0  330.893356
#
#                      pred_time      rmse state
# 2024-09-06 06:01:00   0.968992  0.001371  full
# 2024-09-06 06:11:00   0.969057  0.005825  full
# ---------------OUTPUT: 599.4059469114181
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 599.4059469114181, 'pred_time': 0.9843354225158691, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 7: took 0.99 seconds
#
#
# - Sleeping for 2.01 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 8..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 06:21:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 06:21:00
#
# ---------------------head start loop: {'irradiance': 173.0, 'temperature': 15.1, 'true_power': 0.0, 'pred_power': 599.4059469114181, 'pred_time': 0.9843354225158691, 'rmse': 0.011067020280388848, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 06:21:00
# ---------------INPUT:                      irradiance  temperature  true_power  pred_power  \
# 2024-09-06 06:11:00       144.0         14.7         0.0  330.893356
# 2024-09-06 06:21:00       173.0         15.1         0.0  599.405947
#
#                      pred_time      rmse state
# 2024-09-06 06:11:00   0.969057  0.005825  full
# 2024-09-06 06:21:00   0.984335  0.011067  full
# ---------------OUTPUT: 671.5741827090328
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 671.5741827090328, 'pred_time': 1.1034998893737793, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 8: took 1.11 seconds
#
#
# - Sleeping for 1.89 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 9..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 06:31:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 06:31:00
#
# ---------------------head start loop: {'irradiance': 203.0, 'temperature': 15.5, 'true_power': 0.0, 'pred_power': 671.5741827090328, 'pred_time': 1.1034998893737793, 'rmse': 0.014574232346157841, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 06:31:00
# ---------------INPUT:                      irradiance  temperature  true_power  pred_power  \
# 2024-09-06 06:21:00       173.0         15.1         0.0  599.405947
# 2024-09-06 06:31:00       203.0         15.5         0.0  671.574183
#
#                      pred_time      rmse state
# 2024-09-06 06:21:00   0.984335  0.011067  full
# 2024-09-06 06:31:00   1.103500  0.014574  full
# ---------------OUTPUT: 813.1942432446695
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 813.1942432446695, 'pred_time': 0.9784832000732422, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 9: took 0.98 seconds
#
#
# - Sleeping for 2.02 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 10..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 06:41:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 06:41:00
#
# ---------------------head start loop: {'irradiance': 235.0, 'temperature': 15.9, 'true_power': 0.0, 'pred_power': 813.1942432446695, 'pred_time': 0.9784832000732422, 'rmse': 0.018105152043020198, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 06:41:00
# ---------------INPUT:                      irradiance  temperature  true_power  pred_power  \
# 2024-09-06 06:31:00       203.0         15.5         0.0  671.574183
# 2024-09-06 06:41:00       235.0         15.9         0.0  813.194243
#
#                      pred_time      rmse state
# 2024-09-06 06:31:00   1.103500  0.014574  full
# 2024-09-06 06:41:00   0.978483  0.018105  full
# ---------------OUTPUT: 960.1175503534955
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 960.1175503534955, 'pred_time': 0.9861605167388916, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 10: took 0.99 seconds
#
#
# - Sleeping for 2.01 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 11..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 06:51:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 06:51:00
#
# ---------------------head start loop: {'irradiance': 267.0, 'temperature': 16.2, 'true_power': 0.0, 'pred_power': 960.1175503534955, 'pred_time': 0.9861605167388916, 'rmse': 0.021705809612793843, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 06:51:00
# ---------------INPUT:                      irradiance  temperature  true_power  pred_power  \
# 2024-09-06 06:41:00       235.0         15.9         0.0  813.194243
# 2024-09-06 06:51:00       267.0         16.2         0.0  960.117550
#
#                      pred_time      rmse state
# 2024-09-06 06:41:00   0.978483  0.018105  full
# 2024-09-06 06:51:00   0.986161  0.021706  full
# ---------------OUTPUT: 1091.429675830691
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 1091.429675830691, 'pred_time': 0.9993178844451904, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 11: took 1.00 seconds
#
#
# - Sleeping for 2.00 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 12..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 07:01:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 07:01:00
#
# ---------------------head start loop: {'irradiance': 295.0, 'temperature': 16.8, 'true_power': 15.2721329501, 'pred_power': 1091.429675830691, 'pred_time': 0.9993178844451904, 'rmse': 0.02512529201350198, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 07:01:00
# ---------------INPUT:                      irradiance  temperature  true_power   pred_power  \
# 2024-09-06 06:51:00       267.0         16.2    0.000000   960.117550
# 2024-09-06 07:01:00       295.0         16.8   15.272133  1091.429676
#
#                      pred_time      rmse state
# 2024-09-06 06:51:00   0.986161  0.021706  full
# 2024-09-06 07:01:00   0.999318  0.025125  full
# ---------------OUTPUT: 1204.3380662855134
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 1204.3380662855134, 'pred_time': 0.9658687114715576, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 12: took 0.97 seconds
#
#
# - Sleeping for 2.03 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 13..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 07:11:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 07:11:00
#
# ---------------------head start loop: {'irradiance': 330.0, 'temperature': 17.3, 'true_power': 70.225344245, 'pred_power': 1204.3380662855134, 'pred_time': 0.9658687114715576, 'rmse': 0.02805602321949561, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 07:11:00
# ---------------INPUT:                      irradiance  temperature  true_power   pred_power  \
# 2024-09-06 07:01:00       295.0         16.8   15.272133  1091.429676
# 2024-09-06 07:11:00       330.0         17.3   70.225344  1204.338066
#
#                      pred_time      rmse state
# 2024-09-06 07:01:00   0.999318  0.025125  full
# 2024-09-06 07:11:00   0.965869  0.028056  full
# ---------------OUTPUT: 1390.178119595022
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 1390.178119595022, 'pred_time': 1.2936851978302002, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 13: took 1.30 seconds
#
#
# - Sleeping for 1.70 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 14..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 07:21:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 07:21:00
#
# ---------------------head start loop: {'irradiance': 353.0, 'temperature': 17.6, 'true_power': 166.61653495, 'pred_power': 1390.178119595022, 'pred_time': 1.2936851978302002, 'rmse': 0.03085219790939009, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 07:21:00
# ---------------INPUT:                      irradiance  temperature  true_power   pred_power  \
# 2024-09-06 07:11:00       330.0         17.3   70.225344  1204.338066
# 2024-09-06 07:21:00       353.0         17.6  166.616535  1390.178120
#
#                      pred_time      rmse state
# 2024-09-06 07:11:00   0.965869  0.028056  full
# 2024-09-06 07:21:00   1.293685  0.030852  full
# ---------------OUTPUT: 1502.5042549868494
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 1502.5042549868494, 'pred_time': 1.0553631782531738, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 14: took 1.06 seconds
#
#
# - Sleeping for 1.94 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 15..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 07:31:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 07:31:00
#
# ---------------------head start loop: {'irradiance': 373.0, 'temperature': 18.1, 'true_power': 261.91533948, 'pred_power': 1502.5042549868494, 'pred_time': 1.0553631782531738, 'rmse': 0.033172168481079414, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 07:31:00
# ---------------INPUT:                      irradiance  temperature  true_power   pred_power  \
# 2024-09-06 07:21:00       353.0         17.6  166.616535  1390.178120
# 2024-09-06 07:31:00       373.0         18.1  261.915339  1502.504255
#
#                      pred_time      rmse state
# 2024-09-06 07:21:00   1.293685  0.030852  full
# 2024-09-06 07:31:00   1.055363  0.033172  full
# ---------------OUTPUT: 1639.7534785483117
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 1639.7534785483117, 'pred_time': 0.9784431457519531, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 15: took 0.99 seconds
#
#
# - Sleeping for 2.01 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 16..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 07:41:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 07:41:00
#
# ---------------------head start loop: {'irradiance': 376.0, 'temperature': 18.2, 'true_power': 314.89952289, 'pred_power': 1639.7534785483117, 'pred_time': 0.9784431457519531, 'rmse': 0.035472186487571625, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 07:41:00
# ---------------INPUT:                      irradiance  temperature  true_power   pred_power  \
# 2024-09-06 07:31:00       373.0         18.1  261.915339  1502.504255
# 2024-09-06 07:41:00       376.0         18.2  314.899523  1639.753479
#
#                      pred_time      rmse state
# 2024-09-06 07:31:00   1.055363  0.033172  full
# 2024-09-06 07:41:00   0.978443  0.035472  full
# ---------------OUTPUT: 1638.325475881627
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 1638.325475881627, 'pred_time': 1.1608548164367676, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 16: took 1.16 seconds
#
#
# - Sleeping for 1.84 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 17..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 07:51:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 07:51:00
#
# ---------------------head start loop: {'irradiance': 446.0, 'temperature': 18.4, 'true_power': 312.15468002, 'pred_power': 1638.325475881627, 'pred_time': 1.1608548164367676, 'rmse': 0.03738995916561452, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 07:51:00
# ---------------INPUT:                      irradiance  temperature  true_power   pred_power  \
# 2024-09-06 07:41:00       376.0         18.2  314.899523  1639.753479
# 2024-09-06 07:51:00       446.0         18.4  312.154680  1638.325476
#
#                      pred_time      rmse state
# 2024-09-06 07:41:00   0.978443  0.035472  full
# 2024-09-06 07:51:00   1.160855  0.037390  full
# ---------------OUTPUT: 2042.3413603782005
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 2042.3413603782005, 'pred_time': 1.1986651420593262, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 17: took 1.21 seconds
#
#
# - Sleeping for 1.79 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 18..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 08:01:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 08:01:00
#
# ---------------------head start loop: {'irradiance': 457.0, 'temperature': 18.9, 'true_power': 367.79901182, 'pred_power': 2042.3413603782005, 'pred_time': 1.1986651420593262, 'rmse': 0.04052415772010587, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 08:01:00
# ---------------INPUT:                      irradiance  temperature  true_power   pred_power  \
# 2024-09-06 07:51:00       446.0         18.4  312.154680  1638.325476
# 2024-09-06 08:01:00       457.0         18.9  367.799012  2042.341360
#
#                      pred_time      rmse state
# 2024-09-06 07:51:00   1.160855  0.037390  full
# 2024-09-06 08:01:00   1.198665  0.040524  full
# ---------------OUTPUT: 2121.160361635831
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 2121.160361635831, 'pred_time': 1.0132083892822266, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 18: took 1.02 seconds
#
#
# - Sleeping for 1.98 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 19..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 08:11:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 08:11:00
#
# ---------------------head start loop: {'irradiance': 510.0, 'temperature': 19.1, 'true_power': 494.1290645000001, 'pred_power': 2121.160361635831, 'pred_time': 1.0132083892822266, 'rmse': 0.04293766453034335, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 08:11:00
# ---------------INPUT:                      irradiance  temperature  true_power   pred_power  \
# 2024-09-06 08:01:00       457.0         18.9  367.799012  2042.341360
# 2024-09-06 08:11:00       510.0         19.1  494.129065  2121.160362
#
#                      pred_time      rmse state
# 2024-09-06 08:01:00   1.198665  0.040524  full
# 2024-09-06 08:11:00   1.013208  0.042938  full
# ---------------OUTPUT: 2457.166450279963
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 2457.166450279963, 'pred_time': 0.9863913059234619, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 19: took 0.99 seconds
#
#
# - Sleeping for 2.01 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 20..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 08:21:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 08:21:00
#
# ---------------------head start loop: {'irradiance': 527.0, 'temperature': 19.3, 'true_power': 708.70346116, 'pred_power': 2457.166450279963, 'pred_time': 0.9863913059234619, 'rmse': 0.04546734385403777, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 08:21:00
# ---------------INPUT:                      irradiance  temperature  true_power   pred_power  \
# 2024-09-06 08:11:00       510.0         19.1  494.129065  2121.160362
# 2024-09-06 08:21:00       527.0         19.3  708.703461  2457.166450
#
#                      pred_time      rmse state
# 2024-09-06 08:11:00   1.013208  0.042938  full
# 2024-09-06 08:21:00   0.986391  0.045467  full
# ---------------OUTPUT: 2604.479485899552
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 2604.479485899552, 'pred_time': 0.9770801067352295, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 20: took 0.98 seconds
#
#
# - Sleeping for 2.02 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 21..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 08:31:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 08:31:00
#
# ---------------------head start loop: {'irradiance': 548.0, 'temperature': 19.6, 'true_power': 1018.24601672, 'pred_power': 2604.479485899552, 'pred_time': 0.9770801067352295, 'rmse': 0.04707856479201714, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 08:31:00
# ---------------INPUT:                      irradiance  temperature   true_power   pred_power  \
# 2024-09-06 08:21:00       527.0         19.3   708.703461  2457.166450
# 2024-09-06 08:31:00       548.0         19.6  1018.246017  2604.479486
#
#                      pred_time      rmse state
# 2024-09-06 08:21:00   0.986391  0.045467  full
# 2024-09-06 08:31:00   0.977080  0.047079  full
# ---------------OUTPUT: 2840.068199931241
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 2840.068199931241, 'pred_time': 0.985980749130249, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 21: took 0.99 seconds
#
#
# - Sleeping for 2.01 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 22..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 08:41:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 08:41:00
#
# ---------------------head start loop: {'irradiance': 574.0, 'temperature': 19.9, 'true_power': 1429.8886207, 'pred_power': 2840.068199931241, 'pred_time': 0.985980749130249, 'rmse': 0.04798338136739352, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 08:41:00
# ---------------INPUT:                      irradiance  temperature   true_power   pred_power  \
# 2024-09-06 08:31:00       548.0         19.6  1018.246017  2604.479486
# 2024-09-06 08:41:00       574.0         19.9  1429.888621  2840.068200
#
#                      pred_time      rmse state
# 2024-09-06 08:31:00   0.977080  0.047079  full
# 2024-09-06 08:41:00   0.985981  0.047983  full
# ---------------OUTPUT: 3136.25268427708
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 3136.25268427708, 'pred_time': 1.0990419387817383, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 22: took 1.10 seconds
#
#
# - Sleeping for 1.90 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 23..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 08:51:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 08:51:00
#
# ---------------------head start loop: {'irradiance': 598.0, 'temperature': 20.4, 'true_power': 1989.4772688, 'pred_power': 3136.25268427708, 'pred_time': 1.0990419387817383, 'rmse': 0.04817091111453886, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 08:51:00
# ---------------INPUT:                      irradiance  temperature   true_power   pred_power  \
# 2024-09-06 08:41:00       574.0         19.9  1429.888621  2840.068200
# 2024-09-06 08:51:00       598.0         20.4  1989.477269  3136.252684
#
#                      pred_time      rmse state
# 2024-09-06 08:41:00   0.985981  0.047983  full
# 2024-09-06 08:51:00   1.099042  0.048171  full
# ---------------OUTPUT: 3499.867214094311
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 3499.867214094311, 'pred_time': 0.9801788330078125, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 23: took 0.98 seconds
#
#
# - Sleeping for 2.02 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 24..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 09:01:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 09:01:00
#
# ---------------------head start loop: {'irradiance': 621.0, 'temperature': 20.6, 'true_power': 2638.1286006, 'pred_power': 3499.867214094311, 'pred_time': 0.9801788330078125, 'rmse': 0.047829701174973274, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 09:01:00
# ---------------INPUT:                      irradiance  temperature   true_power   pred_power  \
# 2024-09-06 08:51:00       598.0         20.4  1989.477269  3136.252684
# 2024-09-06 09:01:00       621.0         20.6  2638.128601  3499.867214
#
#                      pred_time      rmse state
# 2024-09-06 08:51:00   1.099042  0.048171  full
# 2024-09-06 09:01:00   0.980179  0.047830  full
# ---------------OUTPUT: 3965.2314423403413
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 3965.2314423403413, 'pred_time': 0.9846310615539551, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 24: took 0.99 seconds
#
#
# - Sleeping for 2.01 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 25..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 09:11:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 09:11:00
#
# ---------------------head start loop: {'irradiance': 643.0, 'temperature': 20.7, 'true_power': 3398.3232779, 'pred_power': 3965.2314423403413, 'pred_time': 0.9846310615539551, 'rmse': 0.04714587823670439, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 09:11:00
# ---------------INPUT:                      irradiance  temperature   true_power   pred_power  \
# 2024-09-06 09:01:00       621.0         20.6  2638.128601  3499.867214
# 2024-09-06 09:11:00       643.0         20.7  3398.323278  3965.231442
#
#                      pred_time      rmse state
# 2024-09-06 09:01:00   0.980179  0.047830  full
# 2024-09-06 09:11:00   0.984631  0.047146  full
# ---------------OUTPUT: 4480.802855083425
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 4480.802855083425, 'pred_time': 0.9893677234649658, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 25: took 0.99 seconds
#
#
# - Sleeping for 2.01 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 26..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 09:21:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 09:21:00
#
# ---------------------head start loop: {'irradiance': 664.0, 'temperature': 21.1, 'true_power': 4096.6677202, 'pred_power': 4480.802855083425, 'pred_time': 0.9893677234649658, 'rmse': 0.04635698498998948, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 09:21:00
# ---------------INPUT:                      irradiance  temperature   true_power   pred_power  \
# 2024-09-06 09:11:00       643.0         20.7  3398.323278  3965.231442
# 2024-09-06 09:21:00       664.0         21.1  4096.667720  4480.802855
#
#                      pred_time      rmse state
# 2024-09-06 09:11:00   0.984631  0.047146  full
# 2024-09-06 09:21:00   0.989368  0.046357  full
# ---------------OUTPUT: 5094.3585943968255
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 5094.3585943968255, 'pred_time': 1.1072423458099365, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 26: took 1.11 seconds
#
#
# - Sleeping for 1.89 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 27..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 09:31:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 09:31:00
#
# ---------------------head start loop: {'irradiance': 682.0, 'temperature': 21.7, 'true_power': 4617.172147499999, 'pred_power': 5094.3585943968255, 'pred_time': 1.1072423458099365, 'rmse': 0.04568154271232656, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 09:31:00
# ---------------INPUT:                      irradiance  temperature   true_power   pred_power  \
# 2024-09-06 09:21:00       664.0         21.1  4096.667720  4480.802855
# 2024-09-06 09:31:00       682.0         21.7  4617.172147  5094.358594
#
#                      pred_time      rmse state
# 2024-09-06 09:21:00   0.989368  0.046357  full
# 2024-09-06 09:31:00   1.107242  0.045682  full
# ---------------OUTPUT: 5671.287701701964
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 5671.287701701964, 'pred_time': 1.0205607414245605, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 27: took 1.02 seconds
#
#
# - Sleeping for 1.98 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 28..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 09:41:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 09:41:00
#
# ---------------------head start loop: {'irradiance': 701.0, 'temperature': 21.6, 'true_power': 4969.3963081, 'pred_power': 5671.287701701964, 'pred_time': 1.0205607414245605, 'rmse': 0.04526176459627164, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 09:41:00
# ---------------INPUT:                      irradiance  temperature   true_power   pred_power  \
# 2024-09-06 09:31:00       682.0         21.7  4617.172147  5094.358594
# 2024-09-06 09:41:00       701.0         21.6  4969.396308  5671.287702
#
#                      pred_time      rmse state
# 2024-09-06 09:31:00   1.107242  0.045682  full
# 2024-09-06 09:41:00   1.020561  0.045262  full
# ---------------OUTPUT: 6054.741650232887
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 6054.741650232887, 'pred_time': 0.9983339309692383, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 28: took 1.00 seconds
#
#
# - Sleeping for 2.00 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 29..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 09:51:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 09:51:00
#
# ---------------------head start loop: {'irradiance': 714.0, 'temperature': 21.1, 'true_power': 6072.0152745, 'pred_power': 6054.741650232887, 'pred_time': 0.9983339309692383, 'rmse': 0.04447478241150886, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 09:51:00
# ---------------INPUT:                      irradiance  temperature   true_power   pred_power  \
# 2024-09-06 09:41:00       701.0         21.6  4969.396308  5671.287702
# 2024-09-06 09:51:00       714.0         21.1  6072.015274  6054.741650
#
#                      pred_time      rmse state
# 2024-09-06 09:41:00   1.020561  0.045262  full
# 2024-09-06 09:51:00   0.998334  0.044475  full
# ---------------OUTPUT: 6790.124117516034
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 6790.124117516034, 'pred_time': 0.9822607040405273, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 29: took 0.99 seconds
#
#
# - Sleeping for 2.01 seconds..
# - Done Sleeping ! ############################################################################################| (100%)
#
#
# commencing loop no. 30..
#
# data_sources.hist_dataset - Retrieving existing merged dataset
# HELLOOOOO : DatetimeIndex(['2024-09-06 10:01:00'], dtype='datetime64[ns]', name='timestamp', freq=None),
# 2024-09-06 10:01:00
#
# ---------------------head start loop: {'irradiance': 722.0, 'temperature': 21.6, 'true_power': 6589.521734200001, 'pred_power': 6790.124117516034, 'pred_time': 0.9822607040405273, 'rmse': 0.04375893244479864, 'state': 'full'}
# ahead start loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# ---------------TIME: 2024-09-06 10:01:00
# ---------------INPUT:                      irradiance  temperature   true_power   pred_power  \
# 2024-09-06 09:51:00       714.0         21.1  6072.015274  6054.741650
# 2024-09-06 10:01:00       722.0         21.6  6589.521734  6790.124118
#
#                      pred_time      rmse state
# 2024-09-06 09:51:00   0.998334  0.044475  full
# 2024-09-06 10:01:00   0.982261  0.043759  full
# ---------------OUTPUT: 7677.548626911192
#
# ---------------------head end loop: {'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': 7677.548626911192, 'pred_time': 1.0744843482971191, 'rmse': -1, 'state': 'prediction'}
# ahead end loop:[{'irradiance': -1, 'temperature': -1, 'true_power': -1, 'pred_power': -1, 'pred_time': -1, 'rmse': -1, 'state': 'empty'}]
#
#
# .. finished loop no. 30: took 1.08 seconds
#
#
# - Sleeping for 1.92 seconds..
# stop button pressed##########################                                                                | (35%))
#
# Stop requested.
#
# - Done Sleeping !
#
#
# Simulation ended
#
# ------------------
# C:\Users\Sara\Downloads\pv-framework\src\utils.py:57: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(scope1)
# C:\Users\Sara\Downloads\pv-framework\src\utils.py:106: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(scope1)
